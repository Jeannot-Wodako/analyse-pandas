# %%
x=54
y=24
T=x+y
print(T)
# Out:
# 78

# %%
Nom = "WODAKO"
Prenoms = "Kossi Jeannot"
Age = "26"
print(f"bonjour, je m'apelle {Nom} {Prenoms} et j'ai {Age}")
# Out:
# bonjour, je m'apelle WODAKO Kossi Jeannot et j'ai 26

# %% [markdown]
# je vais mettre en appliation  l'exercice de R.

# %%
Nom = "WODAKO"
Prenoms = "Kossi Jeannot"
Age = 45

print(f"bonjour, je m'apelle {Nom} {Prenoms} et j'ai {Age}")
Nom = "WODAKO"
Prenoms = "Kossi Jeannot"
Age = 45+5
print(f"je suis {Nom} {Prenoms} et mon nouvel agé est {Age}")
# Out:
# bonjour, je m'apelle WODAKO Kossi Jeannot et j'ai 45
# je suis WODAKO Kossi Jeannot et mon nouvel agé est 50

# %%
nom = "Jean"
age = 25
taille = 1.80
est_etudiant = True

# Afficher les valeurs des quatres variables
print(f"Nom: {nom}")
print(f"Age: {age}")
print(f"Taille: {taille}")
print(f"Est étudiant: {est_etudiant}")

# Afficher les types des quatres variables
print(f"Type nom: {type(nom)}")
print(f"Type age: {type(age)}")
print(f"Type taille: {type(taille)}")
print(f"Type est étudiant: {type(est_etudiant)}")
# Out:
# Nom: Jean
# Age: 25
# Taille: 1.8
# Est étudiant: True
# Type nom: <class 'str'>
# Type age: <class 'int'>
# Type taille: <class 'float'>
# Type est étudiant: <class 'bool'>

# %% [markdown]
# Organiserde groupe de données

# %%
Plate_formes= [ "fecebok", "instagrame", "whathasp"]
Plate_formes[0]
Plate_formes.append("Tiktok")
print(Plate_formes)
# Out:
# ['fecebok', 'instagrame', 'whathasp', 'Tiktok']

# %% [markdown]
# retirer certain valeur

# %%
Plate_formes.remove("instagrame")
print(Plate_formes)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 Plate_formes.remove("instagrame")
#       2 print(Plate_formes)
#
# ValueError: list.remove(x): x not in list

# %%
len(Plate_formes)
# Out:
# 4

# %% [markdown]
# j'ai modifier les élement de la liste

# %%
Plate_formes.append('Twiter')
Plate_formes.append("X")
Plate_formes[1]='Range'
print(Plate_formes)
# Out:
# ['fecebok', 'Range', 'whathasp', 'Tiktok', 'Twiter', 'Twiter', 'X']

# %%
Plate_formes.sort()
print(Plate_formes)
Plate_formes.index()
# Out:
# ['Range', 'Tiktok', 'Twiter', 'Twiter', 'X', 'fecebok', 'whathasp']
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[32], line 3
#       1 Plate_formes.sort()
#       2 print(Plate_formes)
# ----> 3 Plate_formes.index()
#
# TypeError: index expected at least 1 argument, got 0

# %%
ma_liste = []
ma_liste= ['b','r','l','h']
print(ma_liste)
# Out:
# ['b', 'r', 'l', 'h']

# %%
chiffre=["4,5,6,"]
nombre = ['quatre','cinq','six']
combinaison= chiffre+nombre
print(combinaison)
# Out:
# ['4,5,6,', 'quatre', 'cinq', 'six']

# %%
fruit=["pomme","banane","orange"]
print(fruit)
fruit.remove("pomme")
fruit.append('citronnelle')
print(fruit)
# Out:
# ['pomme', 'banane', 'orange']
# ['banane', 'orange', 'citronnelle']

# %%
hauteur = [21,56,45,"rois"]
hauteur.remove("rois")
print(hauteur)
# Out:
# [21, 56, 45]

# %%
# 1. Création de la liste fruits
fruits = ["pomme", "banane", "orange"]

# 2. Ajout de "kiwi"
fruits.append("kiwi")

# 3. Suppression de "orange"
fruits.remove("orange")

# 4. Modification du deuxième élément en "ananas"
fruits[1] = "ananas"

# 5. Affichage de la longueur de la liste
print("La liste fruits contient", len(fruits), "éléments.")

# 6. Tri de la liste par ordre alphabétique et affichage
fruits.sort()
print(fruits)
# Out:
# La liste fruits contient 3 éléments.
# ['ananas', 'kiwi', 'pomme']

# %% [markdown]
# Le dictionnaire

# %%
compagne = {}
compagne["nom"]="les animaux sont tous des chiens"
compagne["nom"]
# Out:
# 'les animaux sont tous des chiens'

# %%
#créer une dictionnaire
nouvelle_compagne = {
    "responsable_de_la_formation":"jean arc",
    "nom_de_la_compagne": "compagne nous aimons",
    "date_de_debut":"01/12/2023",
    "date_de_fin": "03/10/2025",
"influenceurs_importants": ["@MonAmourDeChien", "@MeilleuresFriandisesPourChiens"]}

# %%
print("hello")
45+56
# Out:
# hello
# 101
